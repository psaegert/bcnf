# %%
from bcnf.video_processing import process_video

# %%
frames = process_video(video_path='videos/Ball_Roll_Vid.mp4',
                       gif_name='ball_roll',
                       save_gif=True,
                       ggm_approximation=False,
                       ratio=(16, 9))
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.

# %%
frames = process_video(video_path='videos/Ball_Roll_Vid.mp4',
                       gif_name='ball_roll',
                       save_gif=True,
                       ggm_approximation=True,
                       ratio=(16, 9))
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.
