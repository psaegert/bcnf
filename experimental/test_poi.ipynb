# %%
import numpy as np
from bcnf.simulation.physics import calculate_point_of_impact
import matplotlib.pyplot as plt

# %%
x = calculate_point_of_impact()

# %%
print(x)
# Out:
# [-1.56212164 13.39195654  0.        ]

# %%
x = []
y = []
for i in np.logspace(0.001, 0.00001, 100):
    x.append(i)
    y.append(calculate_point_of_impact(dt=i))

x = np.array(x)
y = np.array(y)

# %%
# plot the first two coordinates in a scatter plot with x as colourscale

plt.scatter(y[:, 0], y[:, 1], c=x, cmap='viridis')
plt.colorbar()
