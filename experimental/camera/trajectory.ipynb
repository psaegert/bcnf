# %%
import numpy as np

from bcnf.simulation.camera import record_trajectory  # camera
# from bcnf.debug.debug_plotting import show_camera_image, debug_plotting
# from bcnf.simulation.observation import simple_2D_camera_observation
from bcnf.simulation.physics import physics_ODE_simulation  # , physics_simulation

# %%
x0 = [0, 0, 1.8]

# %%
# p1 = physics_simulation(x0=args.x0)
p2 = physics_ODE_simulation(x0=x0)

# p1 = simple_2D_camera_observation(p1)
# p2 = simple_2D_camera_observation(p2, noise=True, std=0.05)

record_trajectory(p2, cam_pos=np.array([-25, 0, 1.5]), make_gif=True, gif_path='gifs/trajectory_cam1.gif')
record_trajectory(p2, cam_pos=np.array([0, -25, 1.5]), make_gif=True, gif_path='gifs/trajectory_cam2.gif')
record_trajectory(p2, cam_pos=np.array([25, 0, 1.5]), make_gif=True, gif_path='gifs/trajectory_cam3.gif')
record_trajectory(p2, cam_pos=np.array([0, 25, 1.5]), make_gif=True, gif_path='gifs/trajectory_cam4.gif')

'''
img = camera(
    ball_pos=p2[3],
    ratio=(16, 9),
    fov_horizontal=70.0,
    cam_pos=np.array([-25, 0, 1.5]),
)

show_camera_image(img)
'''

# debug_plotting(p1, p2)
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.
# MovieWriter imagemagick unavailable; using Pillow instead.
# MovieWriter imagemagick unavailable; using Pillow instead.
# MovieWriter imagemagick unavailable; using Pillow instead.
# '\nimg = camera(\n    ball_pos=p2[3],\n    ratio=(16, 9),\n    fov_horizontal=70.0,\n    cam_pos=np.array([-25, 0, 1.5]),\n)\n\nshow_camera_image(img)\n'
